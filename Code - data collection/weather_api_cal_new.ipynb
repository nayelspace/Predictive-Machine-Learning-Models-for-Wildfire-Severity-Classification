# %%
import pandas as pd

# %%
df = pd.read_csv("mapdata_wildfires.csv")

# %%
df.head()
# Out:
#     incident_name incident_is_final incident_date_last_update  \
# 0   IronGate Fire                 Y      2019-07-03T13:12:42Z
# 1    Bikeway Fire                 Y      2019-07-05T09:46:01Z
# 2  Snowstorm Fire                 Y      2019-07-08T07:49:17Z
# 3     Hollow Fire                 Y      2019-07-08T07:50:42Z
# 4    Merced Fire                  Y      2019-07-08T07:51:01Z
#
#   incident_date_created             incident_administrative_unit  \
# 0  2019-06-16T20:33:00Z                   CAL FIRE Siskiyou Unit
# 1  2019-07-05T09:46:01Z                CAL FIRE Santa Clara Unit
# 2  2019-07-05T16:37:04Z     Susanville Bureau of Land Management
# 3  2019-07-03T15:34:12Z                CAL FIRE Santa Clara Unit
# 4  2019-06-29T15:09:52Z  CAL FIRE Madera- Mariposa- Merced Unit
#
#    incident_administrative_unit_url incident_county  \
# 0                               NaN        Siskiyou
# 1                               NaN         Alameda
# 2                               NaN          Lassen
# 3                               NaN     San Joaquin
# 4                               NaN          Merced
#
#                                    incident_location  incident_acres_burned  \
# 0         Deer Run Road, east of Iron Gate Reservoir                   10.0
# 1          Christensen Road, Near Bethany Reservoir                    25.0
# 2                   Snowstorm Rd, south of Ravendale                  263.0
# 3  West Corral Hollow Road, Carnegie State Vehicu...                  283.0
# 4  Off of Merced Fall Road and La Grange Road, Ea...                  210.0
#
#    incident_containment  ... incident_latitude incident_type  \
# 0                 100.0  ...         41.946220      Wildfire
# 1                 100.0  ...         37.469000      Wildfire
# 2                 100.0  ...         40.679318      Wildfire
# 3                 100.0  ...         37.632060      Wildfire
# 4                 100.0  ...         37.312877      Wildfire
#
#                             incident_id  \
# 0  fe63d965-9069-4a96-b9da-99d5fefdaa19
# 1  65e8fbe1-5300-4c90-9f48-0e7bfe55b1bc
# 2  0f965f2f-3977-4ba5-bf7c-29feef27ee82
# 3  89db8bb4-6e3b-4de7-b7d9-287c1a9032c0
# 4  cc06431a-5153-4f66-8ada-07af53c175c3
#
#                                         incident_url  \
# 0  https://www.fire.ca.gov/incidents/2019/6/16/ir...
# 1  https://www.fire.ca.gov/incidents/2019/7/5/bik...
# 2  https://www.fire.ca.gov/incidents/2019/7/5/sno...
# 3  https://www.fire.ca.gov/incidents/2019/7/3/hol...
# 4  https://www.fire.ca.gov/incidents/2019/6/29/me...
#
#   incident_date_extinguished incident_dateonly_extinguished  \
# 0       2019-06-21T14:23:00Z                     2019-06-21
# 1       2019-07-05T03:20:00Z                     2019-07-05
# 2       2019-07-06T07:49:00Z                     2019-07-06
# 3       2019-07-05T07:50:00Z                     2019-07-05
# 4       2019-07-02T15:51:00Z                     2019-07-02
#
#   incident_dateonly_created is_active calfire_incident notification_desired
# 0                2019-06-16         N             True                False
# 1                2019-07-05         N             True                False
# 2                2019-07-05         N            False                False
# 3                2019-07-03         N             True                False
# 4                2019-06-29         N             True                False
#
# [5 rows x 23 columns]

# %%
coordinates_and_dates = []

# Iterate over each row in the dataframe
for _, row in df.iterrows():
    # Extract the incident_latitude, incident_longitude, and incident_dateonly_created values
    lat = row['incident_latitude']
    lon = row['incident_longitude']
    date_created = row['incident_dateonly_created']

    # Create a tuple and append it to the list
    coordinates_and_dates.append((lat, lon, date_created))

# Print the list of tuples
print(coordinates_and_dates)
# Out:
# [(41.94622, -122.40157, '2019-06-16'), (37.469, -121.3697, '2019-07-05'), (40.679318, -120.392768, '2019-07-05'), (37.63206, -121.538382, '2019-07-03'), (37.312877, -120.242411, '2019-06-29'), (37.18904, -121.694968, '2019-07-02'), (37.99837, -122.16201, '2019-07-05'), (40.41741, -122.767256, '2019-07-05'), (39.06066, -121.35014, '2019-07-06'), (33.9885, -117.38417, '2017-12-21'), (34.71796, -120.27077, '2017-12-16'), (38.869036, -119.61865, '2017-12-28'), (34.605358, -120.414875, '2017-12-14'), (35.95191, -120.8092, '2019-07-09'), (33.69055556, -116.953889, '2019-07-11'), (33.8128372, -117.1228851, '2019-07-13'), (37.524378, -120.296551, '2019-07-08'), (37.093243, -121.586846, '2019-07-12'), (37.32555556, -121.76444444, '2019-07-15'), (34.366111, -118.96, '2019-07-14'), (32.566389, -116.7525, '2019-07-12'), (40.463936, -122.435492, '2019-07-12'), (37.944751, -120.84372, '2019-07-15'), (37.016944, -119.934167, '2019-07-15'), (33.56938, -116.07896, '2019-07-12'), (33.514658, -116.7884, '2019-07-16'), (37.962557, -121.468074, '2019-07-16'), (37.420988, -121.371276, '2019-07-18'), (32.794768, -116.839743, '2019-07-17'), (38.115224, -120.78068, '2019-07-18'), (35.004722, -120.435278, '2019-07-24'), (37.241427, -120.027731, '2019-07-21'), (34.9008333, -118.9183333, '2019-07-21'), (39.423833, -121.579738, '2019-07-23'), (34.42386, -117.10318, '2019-07-22'), (33.997528, -117.769766, '2019-07-28'), (38.757636, -120.75664, '2019-07-30'), (32.767649, -116.796032, '2019-07-28'), (37.433192, -121.807258, '2019-07-24'), (38.158333, -122.118889, '2019-07-24'), (38.481258, -122.143942, '2019-07-22'), (38.622058, -121.114095, '2019-08-02'), (38.3525, -121.123611, '2019-08-02'), (35.60989, -118.41204, '2019-07-31'), (33.740219, -117.333728, '2019-08-05'), (35.287373, -118.623651, '2019-08-05'), (40.55924, -122.25409, '2019-08-04'), (40.943799, -120.275298, '2019-08-08'), (37.708743, -121.841879, '2019-08-09'), (37.949747, -120.420058, '2019-08-08'), (39.171091, -121.423281, '2019-08-10'), (33.909792, -117.004667, '2019-08-12'), (38.703889, -120.890556, '2019-08-14'), (39.088333, -122.309167, '2019-08-14'), (34.675542, -118.342239, '2019-08-13'), (38.652475, -120.826165, '2019-08-15'), (37.219717, -121.761974, '2019-08-15'), (38.455, -121.969167, '2019-08-13'), (38.99174, -122.7751, '2019-08-08'), (40.46968, -122.54364, '2019-08-12'), (32.57394, -116.760465, '2019-08-15'), (32.573437, -116.658735, '2019-08-16'), (40.484329, -122.159393, '2019-08-15'), (39.005262, -123.195306, '2019-08-12'), (37.71734, -121.55867, '2019-08-21'), (42.033, -122.175, '2019-08-09'), (33.4506, -116.857817, '2019-08-22'), (33.77777348, -117.487578, '2019-08-25'), (37.034183, -121.45597, '2019-08-25'), (33.463991, -116.914799, '2019-08-27'), (39.892222, -120.029722, '2019-08-24'), (32.557546, -116.873955, '2019-08-25'), (37.718636, -121.657011, '2019-08-31'), (35.906482, -120.992914, '2019-09-01'), (37.545167, -121.596667, '2019-09-02'), (36.40193, -119.030621, '2019-08-31'), (36.600167, -120.8405, '2019-09-02'), (36.732866, -121.39478, '2019-09-04'), (38.910498, -122.642572, '2019-09-04'), (34.353667, -117.343833, '2019-09-02'), (37.178353, -122.07743, '2019-09-03'), (38.955024, -122.833831, '2019-09-07'), (38.898915, -120.946657, '2019-09-03'), (38.017138, -120.945044, '2019-09-05'), (33.496633, -116.631106, '2019-09-10'), (41.512917, -122.740333, '2019-09-07'), (37.32585, -121.110146, '2019-09-11'), (33.854597, -117.270144, '2019-09-12'), (39.470333, -121.412333, '2019-09-06'), (37.492002, -120.401028, '2019-09-13'), (34.630919, -120.187368, '2019-09-09'), (33.900994, -117.170588, '2019-09-21'), (38.20177, -120.827386, '2019-09-22'), (40.612556, -122.039167, '2019-09-24'), (37.467744, -121.842751, '2019-09-21'), (37.838333, -120.625556, '2019-09-23'), (38.332083, -120.67131, '2019-09-25'), (32.87833333, -116.88, '2019-09-25'), (41.43783, -120.23976, '2019-08-02'), (33.9369, -117.3063, '2019-09-07'), (41.150392, -122.634108, '2019-09-07'), (44.734, -120.606, '2019-09 ...

# %%
coordinates_and_dates_small = coordinates_and_dates[:6]

# %%
# Old version when the dataelements parameter = "default"

#weather_data_wildfires_small = pd.read_csv('weather_data_wildfires_small.csv')

#weather_data_wildfires_small = weather_data_wildfires_small.iloc[:,:-2]

#weather_data_wildfires_small.columns = ['Latitude', 'Longitude', 'Date',
       #'Maximum Temperature', 'Minimum Temperature', 'Temperature',
       #'Wind Chill', 'Heat Index', 'Precipitation', 'Snow Depth', 'Wind Speed',
       #'Wind Gust', 'Visibility', 'Cloud Cover', 'Relative Humidity',
       #'Weather Type', 'Conditions']

#weather_data_wildfires_small.to_csv("weather_data_wildfires_small.csv", index = False)

# %%
import requests

def get_weather_data(api_key, lat, lon, date):
    base_url = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/weatherdata/history"

    params = {
        "aggregateHours": "24",
        "startDateTime": date,
        "endDateTime": date,
        "unitGroup": "us",
        "contentType": "csv",
        "dayStartTime": "0:0:00",
        "dayEndTime": "0:0:00",
        "locationMode": "singlelatlong",
        "key": api_key,
        "dataElements": "all",
        "locations": f"{lat},{lon}"
    }

    response = requests.get(base_url, params=params)

    if response.status_code == 200:
        return response.text
    else:
        print(f"Error fetching data: {response.status_code}")
        return None

# API key
api_key = ""

sample_data_error = [(41.94622, -122.40157, '2019-06-16'), (1, 1, '2009-05-25'),
               (40.679318, -120.392768, '2019-07-05')]


# Create a new CSV file and write the results
with open("weather_data_wildfires_intermediate.csv", "w") as csvfile:
    header_written = False
    for lat, lon, date in sample_data_error: # Replace with "coordinates_and_dates" for the full "mapdata_wildfires.csv"
        weather_data = get_weather_data(api_key, lat, lon, date)
        if weather_data:
            lines = weather_data.strip().split("\n")
            if not header_written:
                # Write header with "Latitude", "Longitude", "Date" prepended
                csvfile.write("Latitude,Longitude,Date," + lines[0] + "\n")
                header_written = True

            if len(lines) < 2:
                print(f"No data found for {lat}, {lon} on {date}. Will continue with the next record")
                csvfile.write(f"{lat},{lon},{date},None\n") # Can comment this line out if missing record should not be included in the CSV file
                continue

            data_line = lines[1]
            # Split the data line into fields and remove the first three fields (Address, Address Type, Resolved Address)
            data_fields = data_line.split(",")[3:]

            # Write the latitude, longitude, date, and the rest of the weather data to the CSV file
            csvfile.write(f"{lat},{lon},{date},{','.join(data_fields)}\n")

print("Weather data exported to weather_data_wildfires_intermediate.csv")
# Out:
# No data found for 1, 1 on 2009-05-25. Will continue with the next record
# Weather data exported to weather_data_wildfires_intermediate.csv

# %%
weather_data_wildfires = pd.read_csv('weather_data_wildfires_intermediate.csv')

weather_data_wildfires = weather_data_wildfires.drop(['Address', 'Latitude.1', 'Longitude.1',
       'Name'], axis = 1)

weather_data_wildfires = weather_data_wildfires.iloc[:,:-2]

weather_data_wildfires.columns = ['Latitude', 'Longitude', 'Date',
       'Maximum Temperature', 'Minimum Temperature', 'Temperature',
       'Dew Point', 'Wind Chill', 'Heat Index', 'Precipitation',
       'Precipitation Cover', 'Snow', 'Snow Depth', 'Wind Speed', 'Wind Gust',
       'Wind Direction', 'Visibility', 'Cloud Cover', 'Relative Humidity',
       'Sea Level Pressure', 'Solar Radiation', 'Solar Energy', 'Weather Type',
       'Info', 'Conditions']

weather_data_wildfires.to_csv("weather_data_wildfires.csv", index = False)

print("Weather data exported to weather_data_wildfires.csv")
# Out:
# Weather data exported to weather_data_wildfires.csv

# %%
# Old version when the dataelements parameter = "default"

#weather_data_wildfires = pd.read_csv('weather_data_wildfires.csv')

#weather_data_wildfires = weather_data_wildfires.iloc[:,:-2]

#weather_data_wildfires.columns = ['Latitude', 'Longitude', 'Date',
       #'Maximum Temperature', 'Minimum Temperature', 'Temperature',
       #'Wind Chill', 'Heat Index', 'Precipitation', 'Snow Depth', 'Wind Speed',
       #'Wind Gust', 'Visibility', 'Cloud Cover', 'Relative Humidity',
       #'Weather Type', 'Conditions']

#weather_data_wildfires.to_csv("weather_data_wildfires.csv", index = False)
